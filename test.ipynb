# %%
[<li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/5304346" target="_blank">(주)피플스카우트</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="6A0BB8F7AB04F3C85903BB8E00232791B792D47A6926BF8D8B87C8118E5985C3" f_mem="28D827DA54964B380D043065BBCE8D89F98287B7849464BAC5156E8B2F7588D7" title="관심기업">관심기업</button></div><div class="cl_btm"> </div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2606230002250&amp;src=etc*search" target="_blank">[글로벌 우주항공·첨단소재 기업]<span class="highlight">Python</span> Developer-세일즈 애널리틱스</a><button class="scrap_icon_v2_2606230002250 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2606230002250" jobno="2606230002250" onclick="goCL(this,'19091','job','2606230002250_스크랩');JobPostScrapAdd('IncJob', '', '', '2606230002250', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>서울 강남구 외</span><span>경력 5~11년</span><span>대졸↑</span><span>정규직</span></div><div class="cl_btm"><span>AI·빅데이터,</span> <span>소프트웨어·하드웨어</span></div></div><div class="cell_last"><div class="cl_btm"><span>채용시</span><span>(16일전 등록)</span></div><div class="cl_top"><button bl_job="2606230002250" class="btns_job_submit" onclick="return goCL(this,'19033','search','목록_바로지원_2606230002250');">바로지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="#">주식회사 빅앤딥</a></div><div class="cl_btm"> </div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2607060004093&amp;src=etc*search" target="_blank">[서울 문정] [경력3년이상 4,300~8,500] C++응용소프트웨어, React/<span class="highlight">Python</span>개발자 등</a><button class="scrap_icon_v2_2607060004093 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2607060004093" jobno="2607060004093" onclick="goCL(this,'19091','job','2607060004093_스크랩');JobPostScrapAdd('IncJob', '', '', '2607060004093', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>서울 송파구</span><span>경력 3년↑</span><span>대졸</span><span>정규직</span></div><div class="cl_btm"><span>응용개발자</span></div></div><div class="cell_last"><div class="cl_btm"><span>~07.31 (금)</span><span>(3일전 등록)</span></div><div class="cl_top"></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/1687218404" target="_blank">(주)아톰소프트</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="4CDA7DBF213461AA4A7C2729B400A7978BE69CFA73309259703852872DD26CD2" f_mem="8284E7075A65D0493A3AF0D59D9F3DA954BEED0874496020E8C46B04D546CFAA" title="관심기업">관심기업</button></div><div class="cl_btm"> </div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2607010002637&amp;src=etc*search" target="_blank">기계공학 S/W 개발 인재 채용</a><button class="scrap_icon_v2_2607010002637 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2607010002637" jobno="2607010002637" onclick="goCL(this,'19091','job','2607010002637_스크랩');JobPostScrapAdd('IncJob', '', '', '2607010002637', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>서울 금천구</span><span>경력무관</span><span>대졸↑</span><span>정규직 외</span></div><div class="cl_btm"><span>응용개발자</span></div></div><div class="cell_last"><div class="cl_btm"><span>~07.31 (금)</span><span>(8일전 등록)</span></div><div class="cl_top"><button bl_job="2607010002637" class="btns_job_submit" onclick="return goCL(this,'19033','search','목록_바로지원_2607010002637');">바로지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/5165643" target="_blank">(주) 와이즈오토모티브</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="E236421E55A684A1ECCA9B0F05D48BA58868050FFDB64EA37CB90C8F39B83BB9" f_mem="EBB284394EE51E6E9A0068AA56D3FCB9453CC17C226F10835242E4BFA28855FA" title="관심기업">관심기업</button></div><div class="cl_btm"> <a href="https://job.incruit.com/jobdb_list/searchjob.asp?ct=31&amp;ty=1&amp;cd=1" target="_blank"><span class="sm-txt-icon icon">우수기업</span></a></div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2607070002589&amp;src=etc*search" target="_blank">임베디드 어플리케이션 소프트웨어 /펌웨어 개발자  채용</a><button class="scrap_icon_v2_2607070002589 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2607070002589" jobno="2607070002589" onclick="goCL(this,'19091','job','2607070002589_스크랩');JobPostScrapAdd('IncJob', '', '', '2607070002589', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>서울 서초구</span><span>경력 2년↑</span><span>초대졸</span><span>정규직</span></div><div class="cl_btm"><span>응용개발자</span></div></div><div class="cell_last"><div class="cl_btm"><span>~08.06 (목)</span><span>(2일전 등록)</span></div><div class="cl_top"><button bl_job="2607070002589" class="btns_job_submit" onclick="return goCL(this,'19033','search','목록_바로지원_2607070002589');">바로지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/8666132" target="_blank">프로페셔날핸즈인핸즈코리아(주)</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="5AD28DD3C7DE92D5A2730222E595FC3D3D45A4DAC0BF1E551E16FD47C84C0375" f_mem="1EBA34ED0B78CCC5D0E3D60D6BA2DAE12A6110E732F03A4954334086371F8383" title="관심기업">관심기업</button></div><div class="cl_btm"> <a href="https://job.incruit.com/jobdb_list/searchjob.asp?ct=31&amp;ty=1&amp;cd=1" target="_blank"><span class="sm-txt-icon icon">우수기업</span></a></div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2605200003210&amp;src=etc*search" target="_blank">의류 중견기업 AI Engineer (과장급) 정규직 채용</a><button class="scrap_icon_v2_2605200003210 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2605200003210" jobno="2605200003210" onclick="goCL(this,'19091','job','2605200003210_스크랩');JobPostScrapAdd('IncJob', '', '', '2605200003210', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>서울 강남구</span><span>경력 10~13년</span><span>대졸↑</span><span>정규직</span></div><div class="cl_btm"><span>AI·빅데이터,</span> <span>웹개발자</span></div></div><div class="cell_last"><div class="cl_btm"><span>~07.19 (일)</span><span>(2026.05.20 등록)</span></div><div class="cl_top"><button bl_job="2605200003210" class="btns_job_submit" onclick="return goCL(this,'19033','search','목록_바로지원_2605200003210');">바로지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/1685741694" target="_blank">(주)랩스피너</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="EC6F2DDAB4439EDE03F64025C1F4A6B43990FFCF2C6CDE49232DD43B00DCC405" f_mem="3D9E0020AB7098A6AB161C2F07D7897493639B70EF54FA43F2944F8F33DF8F9C" title="관심기업">관심기업</button></div><div class="cl_btm"> <a href="https://job.incruit.com/jobdb_list/searchjob.asp?ct=31&amp;ty=1&amp;cd=1" target="_blank"><span class="sm-txt-icon icon">우수기업</span></a></div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2607010002505&amp;src=etc*search" target="_blank">[랩스피너] 소프트웨어 연구원 모집</a><button class="scrap_icon_v2_2607010002505 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2607010002505" jobno="2607010002505" onclick="goCL(this,'19091','job','2607010002505_스크랩');JobPostScrapAdd('IncJob', '', '', '2607010002505', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>경기 화성시 외</span><span>경력 3년↑</span><span>대졸↑</span><span>정규직</span></div><div class="cl_btm"><span>IT컨설팅·시스템분석,</span> <span>응용개발자</span></div></div><div class="cell_last"><div class="cl_btm"><span>상시</span><span>(7일전 수정)</span></div><div class="cl_top"><button bl_job="2607010002505" class="btns_job_submit" onclick="return goCL(this,'19033','search','목록_바로지원_2607010002505');">바로지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/1678488855" target="_blank">주식회사가치소프트</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="7AAB6B23AEEA2A9DF4A278B570F24A09F1906745626B52E16DF080EE88C44F9F" f_mem="3CD421ADDE84F6885C8071A26039B9FAB09A9286B802FEEFB12C6F946E67F3AC" title="관심기업">관심기업</button></div><div class="cl_btm"> <a href="https://job.incruit.com/jobdb_list/searchjob.asp?ct=31&amp;ty=1&amp;cd=1" target="_blank"><span class="sm-txt-icon icon">우수기업</span></a></div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2605190002443&amp;src=etc*search" target="_blank">2D/3D Vision SW 및 AI SW개발 프로그래머 채용</a><button class="scrap_icon_v2_2605190002443 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2605190002443" jobno="2605190002443" onclick="goCL(this,'19091','job','2605190002443_스크랩');JobPostScrapAdd('IncJob', '', '', '2605190002443', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>세종</span><span>경력 5년↑</span><span>대졸↑</span><span>정규직</span></div><div class="cl_btm"><span>웹개발자,</span> <span>응용개발자,</span> <span>네트워크·보안엔지니어</span></div></div><div class="cell_last"><div class="cl_btm"><span>~07.18 (토)</span><span>(2026.05.19 수정)</span></div><div class="cl_top"><button bl_job="2605190002443" class="btns_job_submit" onclick="return goCL(this,'19033','search','목록_바로지원_2605190002443');">바로지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="#">지니코딩스쿨컴퓨터학원</a></div><div class="cl_btm"> <a href="https://job.incruit.com/jobdb_list/searchjob.asp?ct=31&amp;ty=1&amp;cd=1" target="_blank"><span class="sm-txt-icon icon">우수기업</span></a></div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2607080001889&amp;src=etc*search" target="_blank">IT교육/프로그래밍강사/컴퓨터강사/AI교육강사</a><button class="scrap_icon_v2_2607080001889 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2607080001889" jobno="2607080001889" onclick="goCL(this,'19091','job','2607080001889_스크랩');JobPostScrapAdd('IncJob', '', '', '2607080001889', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>부산 해운대구</span><span>경력 1년↑</span><span>초대졸</span><span>정규직</span></div><div class="cl_btm"><span>기술·전문강사</span></div></div><div class="cell_last"><div class="cl_btm"><span>채용시</span><span>(21시간전 등록)</span></div><div class="cl_top"></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/1689770839" target="_blank">(주)디자인그룹나인</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="4E3ECB89B2BBD0AA1292E7FB8861BCF7E34099C46BBE9085A657E29F1D5F5CEC" f_mem="55EFE857B5097FB58146C4CEC6D7FF0549B50AF9B86865DB4C00E035EC175CC4" title="관심기업">관심기업</button></div><div class="cl_btm"> <a href="https://job.incruit.com/jobdb_list/searchjob.asp?ct=31&amp;ty=1&amp;cd=1" target="_blank"><span class="sm-txt-icon icon">우수기업</span></a></div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2605130001076&amp;src=etc*search" target="_blank">[파견/7개월/의왕] 대기업 AI 에이전트 개발자 모집</a><button class="scrap_icon_v2_2605130001076 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2605130001076" jobno="2605130001076" onclick="goCL(this,'19091','job','2605130001076_스크랩');JobPostScrapAdd('IncJob', '', '', '2605130001076', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>경기 의왕시</span><span>경력 6년↑</span><span>대졸</span><span>프리랜서</span></div><div class="cl_btm"><span>웹퍼블리셔</span></div></div><div class="cell_last"><div class="cl_btm"><span>채용시</span><span>(2026.05.13 등록)</span></div><div class="cl_top"><button bl_job="2605130001076" class="btns_job_submit" onclick="return goCL(this,'19033','search','목록_바로지원_2605130001076');">바로지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/1670003236" target="_blank">엔아이스퀘어</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="E9DFEE1A256AEAE29CB15D327AA9F6BB22367ECDA7E1BE6F2619AC03E8161D42" f_mem="7829845CA087CF1453538AF1A1ED3876E59757F1324B5735E76859CA6F3D99E4" title="관심기업">관심기업</button></div><div class="cl_btm"> <a href="https://job.incruit.com/jobdb_list/searchjob.asp?ct=31&amp;ty=1&amp;cd=1" target="_blank"><span class="sm-txt-icon icon">우수기업</span></a></div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2605260000117&amp;src=etc*search" target="_blank">응용 시스템 개발자 모집</a><button class="scrap_icon_v2_2605260000117 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2605260000117" jobno="2605260000117" onclick="goCL(this,'19091','job','2605260000117_스크랩');JobPostScrapAdd('IncJob', '', '', '2605260000117', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>광주 광산구</span><span>경력무관</span><span>학력무관</span><span>정규직 외</span></div><div class="cl_btm"><span>AI·빅데이터,</span> <span>시스템엔지니어,</span> <span>IT컨설팅·시스템분석</span></div></div><div class="cell_last"><div class="cl_btm"><span>상시</span><span>(2026.05.26 등록)</span></div><div class="cl_top"><button bl_job="2605260000117" class="btns_job_submit" onclick="return goCL(this,'19033','search','목록_바로지원_2605260000117');">바로지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/2621367" target="_blank">드림에이치알</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="AA4C213C2FFA9516850E0FFCD91D33AFA30DF40AD5AE07A7CE351AC216D39577" f_mem="DFDC1059137B061A80751BF8322491637D042273B2A382DC06AC3E2948ED92F1" title="관심기업">관심기업</button></div><div class="cl_btm"> <a href="https://job.incruit.com/jobdb_list/searchjob.asp?ct=31&amp;ty=1&amp;cd=1" target="_blank"><span class="sm-txt-icon icon">우수기업</span></a></div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2606160001076&amp;src=etc*search" target="_blank">AI 개발자-국내 대표적 보안솔루션 전문기업</a><button class="scrap_icon_v2_2606160001076 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2606160001076" jobno="2606160001076" onclick="goCL(this,'19091','job','2606160001076_스크랩');JobPostScrapAdd('IncJob', '', '', '2606160001076', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>서울</span><span>경력 5년↑</span><span>대졸↑</span><span>정규직</span></div><div class="cl_btm"><span>AI·빅데이터,</span> <span>응용개발자,</span> <span>데이터베이스·DBA</span></div></div><div class="cell_last"><div class="cl_btm"><span>~07.15 (수)</span><span>(23일전 등록)</span></div><div class="cl_top"><button bl_job="2606160001076" class="btns_job_submit" onclick="return goCL(this,'19033','search','목록_바로지원_2606160001076');">바로지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/1690838902" target="_blank">주식회사 프롭핀테크</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="08338DC9D07FBABF02C3221CDD31E70F7D7BD273FBD5CE45E8628CE3D76F754A" f_mem="80ECA29ABA3705BA69CA6A4114ADCBC64630BBEF9958E4DB005644B2D1726B29" title="관심기업">관심기업</button></div><div class="cl_btm"> <a href="https://job.incruit.com/jobdb_list/searchjob.asp?ct=31&amp;ty=1&amp;cd=1" target="_blank"><span class="sm-txt-icon icon">우수기업</span></a></div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2605120005720&amp;src=etc*search" target="_blank">개발자 채용합니다.</a><button class="scrap_icon_v2_2605120005720 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2605120005720" jobno="2605120005720" onclick="goCL(this,'19091','job','2605120005720_스크랩');JobPostScrapAdd('IncJob', '', '', '2605120005720', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>서울 서초구 외</span><span>경력무관</span><span>대졸↑</span><span>정규직 외</span></div><div class="cl_btm"><span>AI·빅데이터,</span> <span>응용개발자,</span> <span>컨텐츠·사이트운영</span></div></div><div class="cell_last"><div class="cl_btm"><span>~07.11 (토)</span><span>(2026.05.12 등록)</span></div><div class="cl_top"><button bl_job="2605120005720" class="btns_job_submit" onclick="return goCL(this,'19033','search','목록_바로지원_2605120005720');">바로지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/7147858" target="_blank">파워에이치알</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="8359198FDB2679E0C24F9CE7B43AC1C7802803BAA56A4DC26A176ACFA1264B56" f_mem="2728E8FBA7D72EBA5C7D24CC13B36B5A82B36B6C3D4DB9743060143A6431FC7E" title="관심기업">관심기업</button></div><div class="cl_btm"> <a href="https://job.incruit.com/jobdb_list/searchjob.asp?ct=31&amp;ty=1&amp;cd=1" target="_blank"><span class="sm-txt-icon icon">우수기업</span></a></div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2606290005681&amp;src=etc*search" target="_blank">[코스피-신용평가업체] 금융권 애플리케이션개발</a><button class="scrap_icon_v2_2606290005681 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2606290005681" jobno="2606290005681" onclick="goCL(this,'19091','job','2606290005681_스크랩');JobPostScrapAdd('IncJob', '', '', '2606290005681', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>서울 영등포구</span><span>신입/경력(15년↓)</span><span>대졸↑</span><span>정규직</span></div><div class="cl_btm"><span>웹개발자,</span> <span>응용개발자,</span> <span>AI·빅데이터</span></div></div><div class="cell_last"><div class="cl_btm"><span>~07.29 (수)</span><span>(10일전 등록)</span></div><div class="cl_top"><button bl_job="2606290005681" class="btns_job_submit" onclick="return goCL(this,'19033','search','목록_바로지원_2606290005681');">바로지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/1690047943" target="_blank">(주)신영에스앤씨</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="9C219263120DD04FFA441FFC84A6A43EE28F0E77F232408F0080D528A227B380" f_mem="C883DF87621CC26B7CD0EDAB57D64E4E8C744EAA5CD428B29720F3992D03EEDD" title="관심기업">관심기업</button></div><div class="cl_btm"> <a href="https://job.incruit.com/jobdb_list/searchjob.asp?ct=31&amp;ty=1&amp;cd=1" target="_blank"><span class="sm-txt-icon icon">우수기업</span></a></div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2606290000316&amp;src=etc*search" target="_blank">AI·데이터 기반 공정/소재 R&amp;D 신규 연구인력 채용</a><button class="scrap_icon_v2_2606290000316 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2606290000316" jobno="2606290000316" onclick="goCL(this,'19091','job','2606290000316_스크랩');JobPostScrapAdd('IncJob', '', '', '2606290000316', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>인천 서구</span><span>경력무관</span><span>대졸↑</span><span>계약직</span></div><div class="cl_btm"><span>AI·빅데이터,</span> <span>기계엔지니어,</span> <span>시스템엔지니어</span></div></div><div class="cell_last"><div class="cl_btm"><span>채용시</span><span>(10일전 등록)</span></div><div class="cl_top"><button bl_job="2606290000316" class="btns_job_submit" onclick="return goCL(this,'19033','search','목록_바로지원_2606290000316');">바로지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/11351847" target="_blank">(주)잡뉴스솔로몬서치</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="23D516B47CAB6D5D46C4B585610DBB03F74FA46C524893C4C48BB12B9BEE2D69" f_mem="6F495C7FF670D710A850462B4A41A9D979F95FB48C693110F94890A5483B17E2" title="관심기업">관심기업</button></div><div class="cl_btm"> <a href="https://job.incruit.com/jobdb_list/searchjob.asp?ct=31&amp;ty=1&amp;cd=1" target="_blank"><span class="sm-txt-icon icon">우수기업</span></a></div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2607040000060&amp;src=etc*search" target="_blank">MLC/ MLO 설계 (경력 5년이상) - 반도체 테스트용 부품 생산기업</a><button class="scrap_icon_v2_2607040000060 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2607040000060" jobno="2607040000060" onclick="goCL(this,'19091','job','2607040000060_스크랩');JobPostScrapAdd('IncJob', '', '', '2607040000060', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>충남 천안시 서북구 외</span><span>경력 5년↑</span><span>대졸↑</span><span>정규직</span></div><div class="cl_btm"><span>전자·반도체,</span> <span>연구개발·R&amp;D</span></div></div><div class="cell_last"><div class="cl_btm"><span>채용시</span><span>(5일전 등록)</span></div><div class="cl_top"><button bl_job="2607040000060" class="btns_job_submit" onclick="return goCL(this,'19033','search','목록_바로지원_2607040000060');">바로지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/1690550140" target="_blank">주식회사 에스더블유엠</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="B4CBF29DA4E7A5A70524BB7AE7E977EA1F58FC1FF976B01D04CB57A8BA85C9D7" f_mem="6D14F058660A9966E57C9D70E117CA9D8D65A45B98BB57083EA9B83460562575" title="관심기업">관심기업</button></div><div class="cl_btm"> <a href="https://job.incruit.com/jobdb_list/searchjob.asp?ct=31&amp;ty=1&amp;cd=1" target="_blank"><span class="sm-txt-icon icon">우수기업</span></a></div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2605130001146&amp;src=etc*search" target="_blank">[SWM] DI테크센터 인프라 운영 엔지니어 경력직 모집</a><button class="scrap_icon_v2_2605130001146 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2605130001146" jobno="2605130001146" onclick="goCL(this,'19091','job','2605130001146_스크랩');JobPostScrapAdd('IncJob', '', '', '2605130001146', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>경기 안양시 동안구 외</span><span>경력 5년↑</span><span>대졸</span><span>정규직</span></div><div class="cl_btm"><span>AI·빅데이터,</span> <span>소프트웨어·하드웨어,</span> <span>IT기술지원</span></div></div><div class="cell_last"><div class="cl_btm"><span>채용시</span><span>(2026.05.13 수정)</span></div><div class="cl_top"><button bl_job="2605130001146" class="btns_job_submit" onclick="return goCL(this,'19033','search','목록_바로지원_2605130001146');">바로지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="#">주식회사TEF</a></div><div class="cl_btm"> </div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2607020001593&amp;src=etc*search" target="_blank">기업부설연구소 연구원 모집(SW개발)</a><button class="scrap_icon_v2_2607020001593 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2607020001593" jobno="2607020001593" onclick="goCL(this,'19091','job','2607020001593_스크랩');JobPostScrapAdd('IncJob', '', '', '2607020001593', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>전남 순천시</span><span>경력 1년↑</span><span>학력무관</span><span>정규직</span></div><div class="cl_btm"><span>응용개발자</span></div></div><div class="cell_last"><div class="cl_btm"><span>~07.31 (금)</span><span>(7일전 등록)</span></div><div class="cl_top"></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/1049049" target="_blank">베스트네트워크(주)</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="5DF189B32D3947CCF0E1A0EF11EC4577AE93712FE2DD08005A513D4D0844718F" f_mem="19366607318B0749390FDC9B9CA8F7DB60E6909F58F718544F75154B131E6426" title="관심기업">관심기업</button></div><div class="cl_btm"> <a href="https://job.incruit.com/jobdb_list/searchjob.asp?ct=31&amp;ty=1&amp;cd=1" target="_blank"><span class="sm-txt-icon icon">우수기업</span></a></div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2607080003643&amp;src=etc*search" target="_blank">43. 데이터 분석 담당자[글로벌 리딩 보험사]</a><button class="scrap_icon_v2_2607080003643 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2607080003643" jobno="2607080003643" onclick="goCL(this,'19091','job','2607080003643_스크랩');JobPostScrapAdd('IncJob', '', '', '2607080003643', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>서울 강남구</span><span>경력 4년↑</span><span>대졸</span><span>정규직</span></div><div class="cl_btm"><span>데이터베이스·DBA</span></div></div><div class="cell_last"><div class="cl_btm"><span>~08.07 (금)</span><span>(16시간전 등록)</span></div><div class="cl_top"><button bl_job="2607080003643" class="btns_job_submit" onclick="return goCL(this,'19033','search','목록_바로지원_2607080003643');">바로지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/1677021177" target="_blank">(주)카카오모빌리티</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="F8EB35FBA2424873FB680F0AE3C36B54A4BF43E50DA660BA5543206A560F97F8" f_mem="E4119F84369FA27353AB23EC84B404CF3C48C3C01A1D2755B79BBA17AF688384" title="관심기업">관심기업</button></div><div class="cl_btm">
<a href="https://job.incruit.com/group/50groupview.asp?groupcd=81" title="카카오">
<span class="sm-txt-icon icon">
                카카오그룹
</span>
</a></div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2606090002512&amp;src=etc*search" target="_blank">데이터 사이언티스트</a><button class="scrap_icon_v2_2606090002512 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2606090002512" jobno="2606090002512" onclick="goCL(this,'19091','job','2606090002512_스크랩');JobPostScrapAdd('IncJob', '', '', '2606090002512', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>경기 성남시 분당구</span><span>신입/경력(5년↑)</span><span>학력무관</span><span>정규직</span></div><div class="cl_btm"><span>AI·빅데이터</span></div></div><div class="cell_last"><div class="cl_btm"><span>상시</span><span>(14일전 수정)</span></div><div class="cl_top"><button bl_job="2606090002512" class="btns_homepage_submit" onclick="goCL(this,'19033',G_SECONDARY_DOMAIN,'목록_홈페이지지원_2606090002512');window.open(G_HOSTNAME_JOB+'/jobdb_info/jobpost.asp?job=2606090002512');">홈페이지 지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="#">(주)지에프</a></div><div class="cl_btm"> </div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2607010001667&amp;src=etc*search" target="_blank">S/W개발자 모집</a><button class="scrap_icon_v2_2607010001667 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2607010001667" jobno="2607010001667" onclick="goCL(this,'19091','job','2607010001667_스크랩');JobPostScrapAdd('IncJob', '', '', '2607010001667', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>광주 광산구</span><span>경력무관</span><span>학력무관</span><span>정규직</span></div><div class="cl_btm"><span>통신·네트워크,</span> <span>전기·전자기능,</span> <span>기술영업,</span> <span>판매·매장직</span></div></div><div class="cell_last"><div class="cl_btm"><span>~07.15 (수)</span><span>(8일전 등록)</span></div><div class="cl_top"></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="#">(주)케이피엠씨</a></div><div class="cl_btm"> </div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2607020004480&amp;src=etc*search" target="_blank">AI-Native 펌웨어 풀스택 개발자 (스마트 공유주차플랫폼)</a><button class="scrap_icon_v2_2607020004480 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2607020004480" jobno="2607020004480" onclick="goCL(this,'19091','job','2607020004480_스크랩');JobPostScrapAdd('IncJob', '', '', '2607020004480', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>서울 서초구</span><span>경력무관</span><span>학력무관</span><span>정규직</span></div><div class="cl_btm"><span>전자·반도체,</span> <span>시스템엔지니어</span></div></div><div class="cell_last"><div class="cl_btm"><span>채용시</span><span>(7일전 등록)</span></div><div class="cl_top"></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/1689744946" target="_blank">에이치알포유(주)</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="E2FC503F42212E2FD58E863FD5B941AFD0C3DACF81EF79A7A518F06C1DE0666B" f_mem="317839F6EC7121041DA8F4E96F174E6E9A62D28BA19B0B368D415984F95E9939" title="관심기업">관심기업</button></div><div class="cl_btm"> </div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2607020002428&amp;src=etc*search" target="_blank">[] 9자리 이상[] 백엔드 엔지니어 (시니어)</a><button class="scrap_icon_v2_2607020002428 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2607020002428" jobno="2607020002428" onclick="goCL(this,'19091','job','2607020002428_스크랩');JobPostScrapAdd('IncJob', '', '', '2607020002428', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>서울</span><span>경력 7년↑</span><span>대졸</span><span>정규직</span></div><div class="cl_btm"><span>AI·빅데이터</span></div></div><div class="cell_last"><div class="cl_btm"><span>~07.11 (토)</span><span>(7일전 등록)</span></div><div class="cl_top"><button bl_job="2607020002428" class="btns_job_submit" onclick="return goCL(this,'19033','search','목록_바로지원_2607020002428');">바로지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/19708178" target="_blank">에이피써치</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="2B722E93AF0B06354EBB72DE61BBC4A0EFCF2650426E2FBB74C27DCD64533118" f_mem="C18A7CAAB742EAB94162894597BFD20072723F0A180E6FAC3E5FA45839A1D4BF" title="관심기업">관심기업</button></div><div class="cl_btm"> </div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2606300003713&amp;src=etc*search" target="_blank">[특허 버티컬 AI 전문 기업] 백엔드 엔지니어</a><button class="scrap_icon_v2_2606300003713 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2606300003713" jobno="2606300003713" onclick="goCL(this,'19091','job','2606300003713_스크랩');JobPostScrapAdd('IncJob', '', '', '2606300003713', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>서울 강남구</span><span>경력 5년↑</span><span>대졸</span><span>정규직</span></div><div class="cl_btm"><span>웹개발자</span></div></div><div class="cell_last"><div class="cl_btm"><span>채용시</span><span>(9일전 등록)</span></div><div class="cl_top"><button bl_job="2606300003713" class="btns_job_submit" onclick="return goCL(this,'19033','search','목록_바로지원_2606300003713');">바로지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/1687160746" target="_blank">(주)엘핀</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="FE8196A630553D95BEB9ADE534C05AB8E6A9F4980F97AC76067C32C28671312A" f_mem="D595BB442D60549EB576DE9485B8D8A18B6215E78481E06E48D68E4B2A382EA1" title="관심기업">관심기업</button></div><div class="cl_btm"> </div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2607010005107&amp;src=etc*search" target="_blank">AI 어플리케이션 개발자 채용</a><button class="scrap_icon_v2_2607010005107 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2607010005107" jobno="2607010005107" onclick="goCL(this,'19091','job','2607010005107_스크랩');JobPostScrapAdd('IncJob', '', '', '2607010005107', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>서울 강서구</span><span>경력무관</span><span>대졸↑</span><span>정규직</span></div><div class="cl_btm"><span>웹개발자,</span> <span>응용개발자</span></div></div><div class="cell_last"><div class="cl_btm"><span>~07.31 (금)</span><span>(8일전 등록)</span></div><div class="cl_top"><button bl_job="2607010005107" class="btns_job_submit" onclick="return goCL(this,'19033','search','목록_바로지원_2607010005107');">바로지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/3074515" target="_blank">비전서치</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="7D2EFBB3917A3CAC3EB241F7ACC9918F899499A8F157F08D460242C6CF1D1C1C" f_mem="3211622FA3E011596E824187ACBF57E877AF70E4B01CCB8A385A3C97B0411AE9" title="관심기업">관심기업</button></div><div class="cl_btm"> </div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2607040000170&amp;src=etc*search" target="_blank">상장 대기업 마케팅 플랫폼 개발 Martech 엔지니어</a><button class="scrap_icon_v2_2607040000170 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2607040000170" jobno="2607040000170" onclick="goCL(this,'19091','job','2607040000170_스크랩');JobPostScrapAdd('IncJob', '', '', '2607040000170', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>서울</span><span>경력 4년↑</span><span>대졸</span><span>정규직</span></div><div class="cl_btm"><span>웹개발자</span></div></div><div class="cell_last"><div class="cl_btm"><span>~07.19 (일)</span><span>(5일전 등록)</span></div><div class="cl_top"><button bl_job="2607040000170" class="btns_job_submit" onclick="return goCL(this,'19033','search','목록_바로지원_2607040000170');">바로지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/130905" target="_blank">써치스퀘어</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="558CF29DB3AA8950EB53A1FE0479CEEE9309096294E14EEF0359878F8A2EB088" f_mem="7D0FEA1CCE88CAA623CBFCF0E637A424A2D5C1154ACACE6B87481292E928C026" title="관심기업">관심기업</button></div><div class="cl_btm"> </div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2606220001269&amp;src=etc*search" target="_blank">AI Engineer (설계,개발,운영)</a><button class="scrap_icon_v2_2606220001269 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2606220001269" jobno="2606220001269" onclick="goCL(this,'19091','job','2606220001269_스크랩');JobPostScrapAdd('IncJob', '', '', '2606220001269', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>서울 중구</span><span>경력 3년↑</span><span>석사↑</span><span>정규직</span></div><div class="cl_btm"><span>AI·빅데이터</span></div></div><div class="cell_last"><div class="cl_btm"><span>~07.12 (일)</span><span>(17일전 등록)</span></div><div class="cl_top"><button bl_job="2606220001269" class="btns_job_submit" onclick="return goCL(this,'19033','search','목록_바로지원_2606220001269');">바로지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/10021429" target="_blank">(주)제이드크로스</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="C98A6DA69578055D5912B19040D35A5EDFE3F4A22B45457249D44E978D575812" f_mem="FD33B72160BEDD4D1D71C8F3DD3F96E10EB71F3A75DED0BD48C6E60886DFDD08" title="관심기업">관심기업</button></div><div class="cl_btm"> </div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2606190002040&amp;src=etc*search" target="_blank">솔루션 S/W 엔지니어 정규직 채용(개발경력 3년이상)</a><button class="scrap_icon_v2_2606190002040 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2606190002040" jobno="2606190002040" onclick="goCL(this,'19091','job','2606190002040_스크랩');JobPostScrapAdd('IncJob', '', '', '2606190002040', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>서울 서초구 외</span><span>신입/경력(1~6년)</span><span>초대졸↑</span><span>정규직</span></div><div class="cl_btm"><span>소프트웨어·하드웨어</span></div></div><div class="cell_last"><div class="cl_btm"><span>~07.19 (일)</span><span>(1일전 수정)</span></div><div class="cl_top"><button bl_job="2606190002040" class="btns_job_submit" onclick="return goCL(this,'19033','search','목록_바로지원_2606190002040');">바로지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="#">(주)씨에스이</a></div><div class="cl_btm"> </div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2607020003710&amp;src=etc*search" target="_blank">연구개발팀 모집합니다.(2명)</a><button class="scrap_icon_v2_2607020003710 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2607020003710" jobno="2607020003710" onclick="goCL(this,'19091','job','2607020003710_스크랩');JobPostScrapAdd('IncJob', '', '', '2607020003710', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>경기 오산시</span><span>경력무관</span><span>학력무관</span><span>정규직</span></div><div class="cl_btm"><span>응용개발자</span></div></div><div class="cell_last"><div class="cl_btm"><span>채용시</span><span>(7일전 등록)</span></div><div class="cl_top"></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/44952" target="_blank">삼양식품</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="A61DAF95384310EAA79DCB5741B04F0E5EEAAAB7057CC5EEAD7AD099C20A4065" f_mem="73616D2CA04805192B7CD7AE8C7B3DAB197D2C90E84B62C27CD761AAEA84B17C" title="관심기업">관심기업</button></div><div class="cl_btm"><a href="https://job.incruit.com/jobdb_list/searchjob.asp?ct=6&amp;ty=1&amp;cd=1" target="_blank"><span class="sm-txt-icon icon">1000대</span></a> </div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2606090000011&amp;src=etc*search" target="_blank">[삼양식품]  IT팀 Back-end개발자</a><button class="scrap_icon_v2_2606090000011 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2606090000011" jobno="2606090000011" onclick="goCL(this,'19091','job','2606090000011_스크랩');JobPostScrapAdd('IncJob', '', '', '2606090000011', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>서울 성북구</span><span>경력 7년↑</span><span>대졸↑</span><span>정규직</span></div><div class="cl_btm"><span>AI·빅데이터,</span> <span>응용개발자</span></div></div><div class="cell_last"><div class="cl_btm"><span>채용시</span><span>(30일전 등록)</span></div><div class="cl_top"><button bl_job="2606090000011" class="btns_homepage_submit" onclick="goCL(this,'19033',G_SECONDARY_DOMAIN,'목록_홈페이지지원_2606090000011');window.open(G_HOSTNAME_JOB+'/jobdb_info/jobpost.asp?job=2606090000011');">홈페이지 지원</button></div></div></li>, <li class="c_col"><div class="cell_first"><div class="cl_top"><a class="cpname" href="https://www.incruit.com/company/1677235740" target="_blank">안진회계법인</a><button class="btns_wish wish_corp_icon wish_heart" f_act="CI" f_comp="8A61141D545B1B0FD6B1251236F1F8E2BB083F402AB0B590D8127586F6BA3CBC" f_mem="06D058981F4D443971185BE587D148298BBD91B093C4826E0521404EBF41D4B1" title="관심기업">관심기업</button></div><div class="cl_btm"><a href="https://job.incruit.com/jobdb_list/searchjob.asp?ct=6&amp;ty=1&amp;cd=1" target="_blank"><span class="sm-txt-icon icon">1000대</span></a> </div></div><div class="cell_mid"><div class="cl_top"><a href="https://job.incruit.com/jobdb_info/jobpost.asp?job=2606010002801&amp;src=etc*search" target="_blank">[딜로이트 컨설팅] 26년 하반기 AI 전문 컨설턴트 경력직</a><button class="scrap_icon_v2_2606010002801 dev_ScrapBt btns_scraps" id="scrap_icon_v2_nor_2606010002801" jobno="2606010002801" onclick="goCL(this,'19091','job','2606010002801_스크랩');JobPostScrapAdd('IncJob', '', '', '2606010002801', 'nor');" title="클릭하면 스크랩됩니다" type="button">스크랩</button></div><div class="cl_md"><span>서울 영등포구</span><span>경력 3년</span><span>대졸</span><span>정규직</span></div><div class="cl_btm"><span>임원·컨설팅,</span> <span>IT컨설팅·시스템분석,</span> <span>AI·빅데이터</span></div></div><div class="cell_last"><div class="cl_btm"><span>~07.31 (금)</span><span>(2026.06.01 등록)</span></div><div class="cl_top"><button bl_job="2606010002801" class="btns_homepage_submit" onclick="goCL(this,'19033',G_SECONDARY_DOMAIN,'목록_홈페이지지원_2606010002801');window.open(G_HOSTNAME_JOB+'/jobdb_info/jobpost.asp?job=2606010002801');">홈페이지 지원</button></div></div></li>]
